# %% [markdown]
# ## Observations and Insights

# %%
# !pip install sklearn

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
# from sklearn import datasets

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_data = pd.merge(mouse_metadata, study_results, on='Mouse ID')

# # Display the data table for preview
mouse_data
# Out:
# Requirement already satisfied: sklearn in c:\users\camer\anaconda3\envs\pythondata\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\camer\anaconda3\envs\pythondata\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\camer\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\camer\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\camer\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\camer\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.0.0)
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
mouse_data['Mouse ID'].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
md_duplicates = mouse_data[mouse_data.duplicated(['Mouse ID','Timepoint'])]
md_duplicates['Mouse ID']
# Out:
# 909    g989
# 911    g989
# 913    g989
# 915    g989
# 917    g989
# Name: Mouse ID, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID. 
# md_duplicates
mouse_data.loc[mouse_data['Mouse ID'] == 'g989']
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = mouse_data.loc[mouse_data['Mouse ID'] != 'g989']
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
clean_df['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

drug_group = clean_df.groupby(["Drug Regimen"])

drug_group_mean = drug_group['Tumor Volume (mm3)'].mean()
drug_group_median = drug_group['Tumor Volume (mm3)'].median()
drug_group_var = drug_group['Tumor Volume (mm3)'].var()
drug_group_std = drug_group['Tumor Volume (mm3)'].std()
drug_group_SEM = drug_group['Tumor Volume (mm3)'].sem()

drug_group_dict = {
    "Mean": drug_group_mean,
    "Median":drug_group_median,
    "Variance":drug_group_var,
    "STD":drug_group_std,
    "SEM":drug_group_SEM,
}

drug_summary_df = pd.DataFrame(drug_group_dict)
drug_summary_df
# Out:
#                    Mean     Median   Variance       STD       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

drug_group['Tumor Volume (mm3)'].agg(['mean','median','var','std','sem'])
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
drug_group_plot = drug_group['Mouse ID'].count()
drug_group_plot.plot(kind="bar", figsize=(20,3))
# drug_group_plot.set_xlabel("Drug Regimen")
# drug_group_plot.set_ylabel("Number of Tests")
plt.title("Number of Tests per Regimen")
plt.ylabel("Number of Tests")
# Out:
# Text(0, 0.5, 'Number of Tests')

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
# clean_df["Drug Regimen"].value_counts()
# drug_group_plot
x_axis = np.arange(len(drug_group_plot))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, drug_group_plot, color='r', alpha=0.8, align="center")
plt.xticks(tick_locations, clean_df['Drug Regimen'].unique(), rotation="vertical")
plt.xlim(-.5, len(x_axis)-.5)
plt.ylim(0, max(drug_group_plot)+30)
plt.title("Total Tests per Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Tests")
# Out:
# Text(0, 0.5, 'Number of Tests')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_count = clean_df["Sex"].value_counts()
plot = gender_count.plot.pie(figsize=(6, 6), autopct="%1.1f%%")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sexes = ['Male','Female']
plt.pie(gender_count, labels=sexes, autopct="%1.1f%%")
plt.axis("equal")
plt.title("Sex", loc='left')
# Out:
# Text(0.0, 1.0, 'Sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
mouse_group = clean_df.groupby(['Mouse ID'])
mouse_max = mouse_group['Timepoint'].max()
mouse_max_df = pd.DataFrame(mouse_max)

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
mouse_merge = pd.merge(clean_df, mouse_max_df, on='Mouse ID')
tumor_vol_loc = mouse_merge.loc[(mouse_merge['Timepoint_x'] == mouse_merge['Timepoint_y'])]
tumor_vol_df = tumor_vol_loc[['Mouse ID','Tumor Volume (mm3)','Drug Regimen']]
tumor_vol_df
# Out:
#      Mouse ID  Tumor Volume (mm3) Drug Regimen
# 9        k403           22.050126     Ramicane
# 19       s185           23.343598    Capomulin
# 29       x401           28.484033    Capomulin
# 39       m601           28.430964    Capomulin
# 49       g791           29.128472     Ramicane
# ...       ...                 ...          ...
# 1846     z314           45.934712     Stelasyn
# 1849     z435           48.710661     Propriva
# 1859     z581           62.754451    Infubinol
# 1869     z795           65.741070     Naftisol
# 1879     z969           73.867845     Naftisol
#
# [248 rows x 3 columns]

# %%
                                # plt.hist(tumor_vol_df['Tumor Volume (mm3)'])
    
#filtered_drug_group = tumor_vol_df.groupby(['Drug Regimen'])

# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for x in tumor_vol_df:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    filtered = tumor_vol_df.loc[tumor_vol_df['Drug Regimen'] == treatment_list[0]]
    tumor_vol_list.append(filtered)
    
    filtered = tumor_vol_df.loc[tumor_vol_df['Drug Regimen'] == treatment_list[1]]
    tumor_vol_list.append(filtered)
    
    filtered = tumor_vol_df.loc[tumor_vol_df['Drug Regimen'] == treatment_list[2]]
    tumor_vol_list.append(filtered)
    
    filtered = tumor_vol_df.loc[tumor_vol_df['Drug Regimen'] == treatment_list[3]]
    tumor_vol_list.append(filtered)
   
    # add subset 

    # Determine outliers using upper and lower bounds

# tumor_vol_list[0]['Tumor Volume (mm3)'].mean()
capomulin_quartiles = tumor_vol_list[0]['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lowerq = capomulin_quartiles[0.25]
upperq = capomulin_quartiles[0.75]
iqr = upperq-lowerq
iqr
# Out:
# 7.781863460000004

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
data = [tumor_vol_list[0]['Tumor Volume (mm3)'],
        tumor_vol_list[1]['Tumor Volume (mm3)'],
        tumor_vol_list[2]['Tumor Volume (mm3)'],
        tumor_vol_list[3]['Tumor Volume (mm3)']
       ]

green_diamond = dict(markerfacecolor='g', marker='D')

fig1, ax1 = plt.subplots()
ax1.set_ylabel('Tumor Size')
ax1.boxplot(data, labels=treatment_list, flierprops=green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2861aff7a90>,
#   <matplotlib.lines.Line2D at 0x2861aff7e10>,
#   <matplotlib.lines.Line2D at 0x2861b00f390>,
#   <matplotlib.lines.Line2D at 0x2861b00f710>,
#   <matplotlib.lines.Line2D at 0x2861b019c50>,
#   <matplotlib.lines.Line2D at 0x2861b019fd0>,
#   <matplotlib.lines.Line2D at 0x2861b16f550>,
#   <matplotlib.lines.Line2D at 0x2861b16f8d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2861b0041d0>,
#   <matplotlib.lines.Line2D at 0x2861b004550>,
#   <matplotlib.lines.Line2D at 0x2861b00fa90>,
#   <matplotlib.lines.Line2D at 0x2861b00fe10>,
#   <matplotlib.lines.Line2D at 0x2861b164390>,
#   <matplotlib.lines.Line2D at 0x2861b164710>,
#   <matplotlib.lines.Line2D at 0x2861b16fc50>,
#   <matplotlib.lines.Line2D at 0x2861b16ffd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2861aff7780>,
#   <matplotlib.lines.Line2D at 0x2861b004f98>,
#   <matplotlib.lines.Line2D at 0x2861b019898>,
#   <matplotlib.lines.Line2D at 0x2861b16f198>],
#  'medians': [<matplotlib.lines.Line2D at 0x2861b0048d0>,
#   <matplotlib.lines.Line2D at 0x2861b0191d0>,
#   <matplotlib.lines.Line2D at 0x2861b164a90>,
#   <matplotlib.lines.Line2D at 0x2861b179390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2861b004c50>,
#   <matplotlib.lines.Line2D at 0x2861b019550>,
#   <matplotlib.lines.Line2D at 0x2861b164e10>,
#   <matplotlib.lines.Line2D at 0x2861b179710>],
#  'means': []}

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
cap_df = clean_df.loc[clean_df['Drug Regimen'] == 'Capomulin']

s185 = cap_df.loc[cap_df['Mouse ID'] == 's185']

s185_tumorvol_y = s185['Tumor Volume (mm3)']

s185_timepoint_x = s185['Timepoint']

mouse_plot = plt.plot(s185_timepoint_x, s185_tumorvol_y, color='green', marker='.', label="'Mouse ID s185")


plt.title("Tumor Size Over Time")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")

handles = 'Mouse ID s185'

plt.legend(handles=mouse_plot, loc="best")
# maximum is tumor size for Capomulin 48.15820939
plt.xlim(0,45)
plt.ylim(20,50)

plt.show()

# rando_mouse = cap_df['Mouse ID'].sample()

# rando_mouse_data = cap_df.loc[cap_df['Mouse ID'] == rando_mouse]

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

cap_id_group = cap_df.groupby(['Mouse ID'])
weight = cap_id_group['Weight (g)'].unique() #max weight it 25, min is 15
av_tum_size = cap_id_group['Tumor Volume (mm3)'].mean() #max tumor size is 45.79

plt.scatter(av_tum_size, weight, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.ylim(weight.min()-1, weight.max()+1)
plt.xlim(av_tum_size.min()-1, av_tum_size.max()+1)

plt.title("Average Tumor Volume Vs. Mouse Weight")
plt.xlabel("Average Tumor Volume")
plt.ylabel("Weight (g)")
# Out:
# Text(0, 0.5, 'Weight (g)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
weight_vol_dict = {
    'Volume': av_tum_size,
    'Weight': weight
    
}

weight_vol_df = pd.DataFrame(weight_vol_dict)
weight_vol_df

volume_r = weight_vol_df['Volume']
weight_r = weight_vol_df['Weight']

# v_slope, v_int, v_r, v_p, v_std_err = stats.linregress(volume_r, weight_r)

# v_fit = v_slope * volume_r + v_int

plt.scatter(volume_r, weight_r, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)
plt.plot(volume_r,weight,"--")
plt.show()

correlation = st.pearsonr(volume_r,weight_r)

correlation

# print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-317-bea605dd029e> in <module>
#      20 plt.show()
#      21
# ---> 22 correlation = st.pearsonr(volume_r,weight_r)
#      23
#      24 correlation
#
# ~\anaconda3\envs\PythonData\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3854         return dtype(np.sign(x[1] - x[0])*np.sign(y[1] - y[0])), 1.0
#    3855
# -> 3856     xmean = x.mean(dtype=dtype)
#    3857     ymean = y.mean(dtype=dtype)
#    3858
#
# ~\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add
